# %% [markdown]
# *Question 1.2: First Session Quiz*
#
# **Answers for week 1**
#
# * Name: Githa Harlaar
# * Username: gharlaar
# * Student s-number: S6396186
# * Group: AS5

# %%
x = 22/7

# %% [markdown]
# $$y=\frac{sin(x)}{x}$$

# %%
pi = 22/7 # Processed on Jupyter Hub

# %% [markdown]
# *1.6.1. Embedding an image with Markdown*

# %% [markdown]
# ![dolphin.jpg](attachment:438d6de1-8758-4483-9ba3-b6d833800bc5.jpg)

# %% [markdown]
# *Question 1.3: Augmented assignment operators*

# %%
x = 6
x *= 5
x *= 4
x *= 3
x *= 2

print(x)
# Out:
# 720

# %% [markdown]
# *Question 1.4: Energy of a single photon*

# %% [markdown]
# import math
# from scipy.constants import h
# from scipy.constants import c
#
# f = 2.42 * 10**28
#
# E = h * f
#
# print(E)

# %% [markdown]
# *Question 1.5: Gravitational pull*

# %%
import math
from scipy.constants import G

M1 = 7.342 * 10**22
M2 = 5.9722 * 10**24
r = 385000.6 * 10**3

F = (G*M1*M2)/r**2

print(F)
# Out:
# 1.974384051807571e+20

# %% [markdown]
# *Question 1.7: Print function*

# %%
x1 = 10
x2 = 22/7
print(x1, end="")
print(x2, end="")
# Out:
# 103.142857142857143

# %% [markdown]
# Normally, the prints would be underneath each other, but now they are directly behind each other. Effectively, there is a space missing. This gives a false answer.

# %% [markdown]
# *Just some practice from the variables booklet*

# %%
import keyword  #Import special code
print (*keyword.kwlist[:10], sep=", ")
print (*keyword.kwlist[10:20], sep=", ")
print (*keyword.kwlist[20:30], sep=", ")
print (*keyword.kwlist[30:], sep=", ")
# Out:
# False, None, True, and, as, assert, async, await, break, class
# continue, def, del, elif, else, except, finally, for, from, global
# if, import, in, is, lambda, nonlocal, not, or, pass, raise
# return, try, while, with, yield

# %%
sun = 2000000000000000000000000000
sun_mass = 1.989e30
sunmass = sun
print (sun)
print(type(sun))
print(sun_mass)
print(type(sun_mass))
print(sunmass)
print(type(sunmass))
# Out:
# 2000000000000000000000000000
# <class 'int'>
# 1.989e+30
# <class 'float'>
# 2000000000000000000000000000
# <class 'int'>

# %%
z = 1 + 2j
print (z, type(z))
z2 = 1.0 + 2.0j
print(z, type(z))
z3 = 1j *1j
print(z3)
# Out:
# (1+2j) <class 'complex'>
# (1+2j) <class 'complex'>
# (-1+0j)

# %% [markdown]
# *Question 1.10: transfer a file between two machines*

# %% [markdown]
# ![Schermafbeelding%202026-02-12%20132549.png](attachment:Schermafbeelding%202026-02-12%20132549.png)

# %% [markdown]
# *Question 1.11: Create a directory structure for your tasks*

# %% [markdown]
# *Question 1.12: Copy your notebooks to another directory*

# %% [markdown]
# *Question 1.13: Commit and push your changes*
